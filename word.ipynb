# %%
from collections import Counter
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from nltk.tokenize import sent_tokenize, word_tokenize

# Read CSV file, get author names and counts.
df = pd.read_csv("ner.csv",encoding = "ISO-8859-1", usecols=['NER'])

counter = Counter(df['NER'])

print(counter)
author_names = counter.keys()
print(author_names)
#print(word_tokenize(author_names))
author_counts = counter.values()
print(author_counts)
# Plot histogram using matplotlib bar().
indexes = np.arange(len(author_names))
width = .3
plt.bar(indexes, author_counts, width)
plt.xticks(indexes + width * 0.5, author_names)
plt.show()
# Out:
# Counter({'Person,Location , Organization , Miscellaneous date, time, number, percentages, monetary expressions , measurement expressions': 4, 'person, location, organization': 3, 'PERSON,NORPNationalities or religious or political groups, FACBuildings, airports, highways, bridges , ORG,GPECountries, cities, states,LOC, PRODUCT, EVENT, WORK_OF_ART, LAW, LANGUAGE, DATE, TIME, PERCENT, MONEY, QUANTITY, ORDINAL': 1, 'Person , proper , Location , Date, Numbers, Organization': 1, 'Person, Location, Organization': 1, 'Person, Location, Organization, Miscellaneous  ': 1, 'Person, Location, Organization, Designation, Abbreviation, Number, Measure, Terms, Time ': 1, 'Person, location, organization, country, other , month, week, party': 1, 'artifact, entertainment, facilities, location, locomotive, materials, organisms, organization, person, plants, count, distance, money, quantity, date, day, period, time , year': 1, 'Person , Location,organization': 1, 'Person, Designation, Organization, Abbreviation, title person, Title-Object, Location, Time, Number, Measure, Terms': 1, ' person, location  , organization ': 1, 'person, organization, location, expressions of times, quantities,number': 1, 'person, location, , organization EX, absolute temporal terms TIMEX , monetary': 1, 'person, location, organization, time, currency, percentage': 1, 'person, location, organization, time': 1})
# dict_keys(['PERSON,NORPNationalities or religious or political groups, FACBuildings, airports, highways, bridges , ORG,GPECountries, cities, states,LOC, PRODUCT, EVENT, WORK_OF_ART, LAW, LANGUAGE, DATE, TIME, PERCENT, MONEY, QUANTITY, ORDINAL', 'Person , proper , Location , Date, Numbers, Organization', 'Person, Location, Organization', 'Person, Location, Organization, Miscellaneous  ', 'Person, Location, Organization, Designation, Abbreviation, Number, Measure, Terms, Time ', 'Person,Location , Organization , Miscellaneous date, time, number, percentages, monetary expressions , measurement expressions', 'Person, location, organization, country, other , month, week, party', 'artifact, entertainment, facilities, location, locomotive, materials, organisms, organization, person, plants, count, distance, money, quantity, date, day, period, time , year', 'Person , Location,organization', 'Person, Designation, Organization, Abbreviation, title person, Title-Object, Location, Time, Number, Measure, Terms', 'person, location, organization', ' person, location  , organization ', 'person, organization, location, expressions of times, quantities,number', 'person, location, , organization EX, absolute temporal terms TIMEX , monetary', 'person, location, organization, time, currency, percentage', 'person, location, organization, time'])
# dict_values([1, 1, 1, 1, 1, 4, 1, 1, 1, 1, 3, 1, 1, 1, 1, 1])
